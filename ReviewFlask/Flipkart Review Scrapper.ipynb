# %% [markdown]
# # Review Scrapper Project for Flipkart

# %%
from flask import Flask, render_template, request, jsonify

# %%
from bs4 import BeautifulSoup as bs # Helps to beautify the specified sources

# %%
from urllib.request import urlopen as urReq

# %% [markdown]
# ## Hit the URL

# %%
flipcart_url = "https://www.flipkart.com/search?q="+"iphone11"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone11'

# %%
response_website = urReq(flipcart_url) # through urReq() we are able to hit the particular url.

# %% [markdown]
# ## Read each and everything on the particular page

# %%
data_flipcart = response_website.read()

# %%
data_flipcart
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.914d0a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %% [markdown]
# ## Beautify the particular data so that it will be readable using beautifulSoup

# %%
beautifyed_html  = bs(data_flipcart,"html.parser") # html.parser--> Parse the data in html format.

# %%
beautifyed_html
# Out:
# <!DOCTYPE html>
# ...

# %%
# List of mobile phone in one page
beautifyed_html.find_all("div" , {"class" : "_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy
# ...

# %%
# Total 30 mobile phone is there on one page
bigbox = beautifyed_html.find_all("div" , {"class" : "_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
# contains information of 1st mobile phone
bigbox[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone11&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,
# ...

# %%
# This is the url of particular phone
bigbox[6].div.div.div.a['href']
# Out:
# '/apple-iphone-11-red-128-gb/p/itm8d14bd0e33a1c?pid=MOBFWQ6BEZTNK59G&lid=LSTMOBFWQ6BEZTNK59G4PTPDM&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=dd01e3d9-24fd-4902-983a-dbd08edb4ba7.MOBFWQ6BEZTNK59G.SEARCH&ppt=None&ppn=None&ssid=h1ilrv8mdc0000001690241198972&qH=d6db477051465f9a'

# %%
# Append the particular phone url(6th prodoct in this case) with the flipkart url so that we can get the complete url

product6 = "https://www.flipkart.com" + bigbox[6].div.div.div.a['href']

# %%
product6
# Out:
# 'https://www.flipkart.com/apple-iphone-11-red-128-gb/p/itm8d14bd0e33a1c?pid=MOBFWQ6BEZTNK59G&lid=LSTMOBFWQ6BEZTNK59G4PTPDM&marketplace=FLIPKART&q=iphone11&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=dd01e3d9-24fd-4902-983a-dbd08edb4ba7.MOBFWQ6BEZTNK59G.SEARCH&ppt=None&ppn=None&ssid=h1ilrv8mdc0000001690241198972&qH=d6db477051465f9a'

# %%
import requests

# %%
# Request the paritcular url
product66 = requests.get(product6)

# %%
# Response 200 means successful execution.
product66
# Out:
# <Response [200]>

# %%
# Encode it in english format
product66.encoding= 'utf-8'

# %%
product6_page = bs(product66.text,"html.parser")

# %%
product6_page
# Out:
# <!DOCTYPE html>
# ...

# %%
all_review = product6_page.find_all('div',{"class" : "_16PBlm"})

# %%
all_review
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Mind-blowing purchase</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Photos super</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_1a51132b9001441cb988bef6ec97ff21.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_6d75e10c033940e4ad234dbbf21d2ac5.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_6829343c419e4679a9a66319f6e26148.jpeg?q=90), url(data
# ...

# %%
len(all_review)
# Out:
# 11

# %%
# Extract the rating
rating = all_review[5].div.div.div.div.text

# %%
rating
# Out:
# '5'

# %%
# Extract the name of reviewer
name = all_review[5].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
name
# Out:
# 'Kuldeep Kumar'

# %%
comment_header = all_review[5].div.div.div.p.text

# %%
comment_header
# Out:
# 'Perfect product!'

# %%
 # Comment of the reviewer
long_review = all_review[5].div.find_all('div' , {'class' : ""})[0].div.text

# %%
long_review
# Out:
# 'V Good all'

# %%
# Date on which reviewer has given the review
date = all_review[5].div.find_all('p', {"class":"_2sc7ZR"})[1].text

# %%
date
# Out:
# 'Apr, 2021'

# %%
# Price of the product
price = product6_page.find_all('div',{"class" : "_30jeq3 _16Jk6d"})[0].text

# %%
price
# Out:
# '₹46,999'

# %%
# Specification of the phone
highlights = product6_page.find_all('div', {'class' : "_2418kt"})[0].text

# %%
highlights
# Out:
# '128 GB ROM15.49 cm (6.1 inch) Liquid Retina HD Display12MP + 12MP | 12MP Front CameraA13 Bionic Chip Processor'

# %%
# This is the list of all the review
all_review
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Mind-blowing purchase</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Photos super</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_1a51132b9001441cb988bef6ec97ff21.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_6d75e10c033940e4ad234dbbf21d2ac5.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_6829343c419e4679a9a66319f6e26148.jpeg?q=90), url(data
# ...

# %%
# Now we need to find out each and every review, ratings, name, date, heading, comments of all the reviewer
for i in all_review:
    price = product6_page.find_all('div',{"class" : "_30jeq3 _16Jk6d"})[0].text
    long_review = i.div.find_all('div' , {'class' : ""})[0].div.text
    date = i.div.find_all('p', {"class":"_2sc7ZR"})[1].text
    comment_header = i.div.div.div.p.text
    name = i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
    rating = i.div.div.div.div.text
    print(name, rating,comment_header, long_review, date, price)
# Out:
# siva sankar 5 Mind-blowing purchase Photos super 2 months ago ₹46,999
# Vishnu Ramakrishnan 5 Classy product Camera is awesomeBest battery backupA performer 👌🏻It will be a real value for money if they provide charger and earphone inbox! Apr, 2021 ₹46,999
# Manish  Deshlahare 5 Terrific Very very good Jul, 2020 ₹46,999
# Flipkart Customer 5 Wonderful This is amazing at all Jan, 2021 ₹46,999
# Vikram rapolu 5 Just wow! Perfect Product!! Aug, 2020 ₹46,999
# Kuldeep Kumar 5 Perfect product! V Good all Apr, 2021 ₹46,999
# vikash  Yadav 5 Must buy! It’s really awesome Sep, 2020 ₹46,999
# Steevan Rattra  5 Best in the market! Good Camera Nov, 2019 ₹46,999
# Abhishek Sachdeva 5 Worth every penny Feeling awesome after getting the delivery of my phone. Dual speakers makes the sound quality very loud. Amazing!! Jan, 2020 ₹46,999
# Dev 5 Terrific purchase Value for money 😍 Jun, 2020 ₹46,999
# ---------------------------------------------------------------------------
# ...

# %%
# Connect to the mysql and store the information
import  mysql.connector as conn
mydb =conn.connect(host = "localhost" , user = 'root' , passwd = "password@123")
cursor = mydb.cursor()
cursor.execute("create database if not exists review")
cursor.execute("create table if not exists review.storereview (price varchar(30) ,comment_header varchar(90), name varchar(90),rating varchar(90),long_review varchar(90))")

# %%
# Store the data in csv file
comment_header = []
rating = []
customer_name = []
review =  []
date = []
price = []
for i in range(len(product6_page)):
    # if i != None:
    comment_header.append(product66[i].div.div.p.text)
    rating.append(product66[i].div.div.div.div.text)
    customer_name.append(product66[i].div.div.find_all("p", {"class":"_2sc7ZR _2V5EHH"})[0].text)
    review.append(product66[i].div.div.find_all("div", {"class":"t-ZTKy"})[0].text)
    date.append(product66[i].div.find_all('p',{"class":"_2sc7ZR"})[1].text)
    price.append(bs_pro_6.find_all("div",{"class":"_30jeq3 _16Jk6d"})[0].text)

dict_data = {"customer_name":customer_name,
            "rating":rating,
            "header":comment_header,
             "price":price,
             "date":date,
             "review":review
            }
df = pd.DataFrame(dict_data)
df.to_csv("flipkart_data.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [175], in <cell line: 8>()
#       7 price = []
#       8 for i in range(len(product6_page)):
#       9     # if i != None:
# ---> 10     comment_header.append(product6[i].div.div.p.text)
#      11     rating.append(product66[i].div.div.div.div.text)
#      12     customer_name.append(product66[i].div.div.find_all("p", {"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'str' object has no attribute 'div'
